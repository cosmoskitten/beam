# %%
import logging
from google.cloud import pubsub_v1

# %%
logger = logging.getLogger()
logger.setLevel(logging.INFO)
logging.debug("test")

# %%
import apache_beam as beam
import apache_beam.transforms.window as window
from apache_beam.runners.interactive import interactive_runner
from apache_beam.options.pipeline_options import PipelineOptions
from apache_beam.options.pipeline_options import StandardOptions
# Out:
# /usr/local/google/home/ningk/workspace/beam/sdks/python/apache_beam/__init__.py:84: UserWarning: Some syntactic constructs of Python 3 are not yet fully supported by Apache Beam.
#   'Some syntactic constructs of Python 3 are not yet fully supported by '
# INFO:root:Generating grammar tables from /usr/lib/python3.6/lib2to3/Grammar.txt
# INFO:root:Generating grammar tables from /usr/lib/python3.6/lib2to3/PatternGrammar.txt

# %%
pipeline_options = PipelineOptions()
pipeline_options.view_as(StandardOptions).streaming = True
p = beam.Pipeline(interactive_runner.InteractiveRunner(),
                  options=pipeline_options)
# p = beam.Pipeline(options=pipeline_options)
print (type(p))
print (id(p))
# Out:
# <class 'apache_beam.pipeline.Pipeline'>
# 140663427991648

# %%
messages = p | "Read" >> beam.io.ReadFromPubSub(subscription='projects/ningk-test-project/subscriptions/test')

# %%
result = p.run()
# Out:
# INFO:root:Running pipeline with DirectRunner.
# /usr/local/google/home/ningk/IdeaProjects/beam_p3_venv/lib/python3.6/site-packages/google/auth/_default.py:66: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK. We recommend that most server applications use service accounts instead. If your application continues to use end user credentials from Cloud SDK, you might receive a "quota exceeded" or "API not enabled" error. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.40.1 (20161225.0304)
#  -->
# <!-- Title: G Pages: 1 -->
# <svg width="921pt" height="188pt"
#  viewBox="0.00 0.00 920.52 188.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 184)">
# <title>G</title>
# <polygon fill="#ffffff" stroke="transparent" points="-4,4 -4,-184 916.519,-184 916.519,4 -4,4"/>
# <!-- Read -->
# <g id="node1" class="node">
# <title>Read</title>
# <ellipse fill="none" stroke="#0000ff" cx="456.2595" cy="-162" rx="28.6953" ry="18"/>
# <text text-anchor="middle" x="456.2595" y="-158.3" font-family="Times,serif" font-size="14.00" fill="#0000ff">Read</text>
# </g>
# <!-- ref_AppliedPTransform_AppliedPTransform_1/_WriteCache_messages,140663428082320,ref_PCollection_PCollection_1 -->
# <g id="node2" class="node">
# <title>ref_AppliedPTransform_AppliedPTransform_1/_WriteCache_messages,140663428082320,ref_PCollection_PCollection_1</title>
# <ellipse fill="none" stroke="#0000ff" cx="456.2595" cy="-90" rx="456.0192" ry="18"/>
# <text text-anchor="middle" x="456.2595" y="-86.3" font-family="Times,serif" font-size="14.00" fill="#0000ff">ref_AppliedPTransform_AppliedPTransform_1/_WriteCache_messages,140663428082320,ref_PCollection_PCollection_1</text>
# </g>
# <!-- Read&#45;&gt;ref_AppliedPTransform_AppliedPTransform_1/_WriteCache_messages,140663428082320,ref_PCollection_PCollection_1 -->
# <g id="edge1" class="edge">
# <title>Read&#45;&gt;ref_AppliedPTransform_AppliedPTransform_1/_WriteCache_messages,140663428082320,ref_PCollection_PCollection_1</title>
# <path fill="none" stroke="#000000" d="M456.2595,-143.8314C456.2595,-136.131 456.2595,-126.9743 456.2595,-118.4166"/>
# <polygon fill="#000000" stroke="#000000" points="459.7596,-118.4132 456.2595,-108.4133 452.7596,-118.4133 459.7596,-118.4132"/>
# </g>
# <!-- leaf4407 -->
# <!-- ref_AppliedPTransform_AppliedPTransform_1/_WriteCache_messages,140663428082320,ref_PCollection_PCollection_1&#45;&gt;leaf4407 -->
# <g id="edge2" class="edge">
# <title>ref_AppliedPTransform_AppliedPTransform_1/_WriteCache_messages,140663428082320,ref_PCollection_PCollection_1&#45;&gt;leaf4407</title>
# <path fill="none" stroke="#000000" d="M456.2595,-71.8314C456.2595,-64.131 456.2595,-54.9743 456.2595,-46.4166"/>
# <polygon fill="#000000" stroke="#000000" points="459.7596,-46.4132 456.2595,-36.4133 452.7596,-46.4133 459.7596,-46.4132"/>
# </g>
# </g>
# </svg>
# WARNING:root:The DirectPipelineResult is being garbage-collected while the DirectRunner is still running the corresponding pipeline. This may lead to incomplete execution of the pipeline if the main thread exits before pipeline completion. Consider using result.wait_until_finish() to wait for completion of pipeline execution.
# /usr/local/google/home/ningk/IdeaProjects/beam_p3_venv/lib/python3.6/site-packages/google/auth/_default.py:66: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK. We recommend that most server applications use service accounts instead. If your application continues to use end user credentials from Cloud SDK, you might receive a "quota exceeded" or "API not enabled" error. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# /usr/local/google/home/ningk/IdeaProjects/beam_p3_venv/lib/python3.6/site-packages/google/auth/_default.py:66: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK. We recommend that most server applications use service accounts instead. If your application continues to use end user credentials from Cloud SDK, you might receive a "quota exceeded" or "API not enabled" error. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# /usr/local/google/home/ningk/IdeaProjects/beam_p3_venv/lib/python3.6/site-packages/google/auth/_default.py:66: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK. We recommend that most server applications use service accounts instead. If your application continues to use end user credentials from Cloud SDK, you might receive a "quota exceeded" or "API not enabled" error. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# /usr/local/google/home/ningk/IdeaProjects/beam_p3_venv/lib/python3.6/site-packages/google/auth/_default.py:66: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK. We recommend that most server applications use service accounts instead. If your application continues to use end user credentials from Cloud SDK, you might receive a "quota exceeded" or "API not enabled" error. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# /usr/local/google/home/ningk/IdeaProjects/beam_p3_venv/lib/python3.6/site-packages/google/auth/_default.py:66: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK. We recommend that most server applications use service accounts instead. If your application continues to use end user credentials from Cloud SDK, you might receive a "quota exceeded" or "API not enabled" error. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %%
message_list = result.get(messages)
logging.info(message_list)
# Out:
# WARNING:root:/tmp/interactive-temp-9u2hx53l
# WARNING:root:get key messages,140663428082320,ref_PCollection_PCollection_1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-625e4cc4c797> in <module>
# ----> 1 message_list = result.get(messages)
#       2 logging.info(message_list)
#
# ~/workspace/beam/sdks/python/apache_beam/runners/interactive/interactive_runner.py in get(self, pcoll)
#     154       return pcoll_list
#     155     else:
# --> 156       raise ValueError('PCollection not available, please run the pipeline.')
#
# ValueError: PCollection not available, please run the pipeline.
# /usr/local/google/home/ningk/IdeaProjects/beam_p3_venv/lib/python3.6/site-packages/google/auth/_default.py:66: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK. We recommend that most server applications use service accounts instead. If your application continues to use end user credentials from Cloud SDK, you might receive a "quota exceeded" or "API not enabled" error. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# /usr/local/google/home/ningk/IdeaProjects/beam_p3_venv/lib/python3.6/site-packages/google/auth/_default.py:66: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK. We recommend that most server applications use service accounts instead. If your application continues to use end user credentials from Cloud SDK, you might receive a "quota exceeded" or "API not enabled" error. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# /usr/local/google/home/ningk/IdeaProjects/beam_p3_venv/lib/python3.6/site-packages/google/auth/_default.py:66: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK. We recommend that most server applications use service accounts instead. If your application continues to use end user credentials from Cloud SDK, you might receive a "quota exceeded" or "API not enabled" error. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# /usr/local/google/home/ningk/IdeaProjects/beam_p3_venv/lib/python3.6/site-packages/google/auth/_default.py:66: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK. We recommend that most server applications use service accounts instead. If your application continues to use end user credentials from Cloud SDK, you might receive a "quota exceeded" or "API not enabled" error. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# /usr/local/google/home/ningk/IdeaProjects/beam_p3_venv/lib/python3.6/site-packages/google/auth/_default.py:66: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK. We recommend that most server applications use service accounts instead. If your application continues to use end user credentials from Cloud SDK, you might receive a "quota exceeded" or "API not enabled" error. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# /usr/local/google/home/ningk/IdeaProjects/beam_p3_venv/lib/python3.6/site-packages/google/auth/_default.py:66: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK. We recommend that most server applications use service accounts instead. If your application continues to use end user credentials from Cloud SDK, you might receive a "quota exceeded" or "API not enabled" error. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# /usr/local/google/home/ningk/IdeaProjects/beam_p3_venv/lib/python3.6/site-packages/google/auth/_default.py:66: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK. We recommend that most server applications use service accounts instead. If your application continues to use end user credentials from Cloud SDK, you might receive a "quota exceeded" or "API not enabled" error. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# /usr/local/google/home/ningk/IdeaProjects/beam_p3_venv/lib/python3.6/site-packages/google/auth/_default.py:66: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK. We recommend that most server applications use service accounts instead. If your application continues to use end user credentials from Cloud SDK, you might receive a "quota exceeded" or "API not enabled" error. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# /usr/local/google/home/ningk/IdeaProjects/beam_p3_venv/lib/python3.6/site-packages/google/auth/_default.py:66: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK. We recommend that most server applications use service accounts instead. If your application continues to use end user credentials from Cloud SDK, you might receive a "quota exceeded" or "API not enabled" error. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# /usr/local/google/home/ningk/IdeaProjects/beam_p3_venv/lib/python3.6/site-packages/google/auth/_default.py:66: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK. We recommend that most server applications use service accounts instead. If your application continues to use end user credentials from Cloud SDK, you might receive a "quota exceeded" or "API not enabled" error. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# /usr/local/google/home/ningk/IdeaProjects/beam_p3_venv/lib/python3.6/site-packages/google/auth/_default.py:66: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK. We recommend that most server applications use service accounts instead. If your application continues to use end user credentials from Cloud SDK, you might receive a "quota exceeded" or "API not enabled" error. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# /usr/local/google/home/ningk/IdeaProjects/beam_p3_venv/lib/python3.6/site-packages/google/auth/_default.py:66: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK. We recommend that most server applications use service accounts instead. If your application continues to use end user credentials from Cloud SDK, you might receive a "quota exceeded" or "API not enabled" error. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# /usr/local/google/home/ningk/IdeaProjects/beam_p3_venv/lib/python3.6/site-packages/google/auth/_default.py:66: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK. We recommend that most server applications use service accounts instead. If your application continues to use end user credentials from Cloud SDK, you might receive a "quota exceeded" or "API not enabled" error. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# /usr/local/google/home/ningk/IdeaProjects/beam_p3_venv/lib/python3.6/site-packages/google/auth/_default.py:66: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK. We recommend that most server applications use service accounts instead. If your application continues to use end user credentials from Cloud SDK, you might receive a "quota exceeded" or "API not enabled" error. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# /usr/local/google/home/ningk/IdeaProjects/beam_p3_venv/lib/python3.6/site-packages/google/auth/_default.py:66: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK. We recommend that most server applications use service accounts instead. If your application continues to use end user credentials from Cloud SDK, you might receive a "quota exceeded" or "API not enabled" error. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# /usr/local/google/home/ningk/IdeaProjects/beam_p3_venv/lib/python3.6/site-packages/google/auth/_default.py:66: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK. We recommend that most server applications use service accounts instead. If your application continues to use end user credentials from Cloud SDK, you might receive a "quota exceeded" or "API not enabled" error. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# /usr/local/google/home/ningk/IdeaProjects/beam_p3_venv/lib/python3.6/site-packages/google/auth/_default.py:66: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK. We recommend that most server applications use service accounts instead. If your application continues to use end user credentials from Cloud SDK, you might receive a "quota exceeded" or "API not enabled" error. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %%
#message_plus_one_list = result.get(messages_plus_one)
#logging.info(message_plus_one_list)

# %%
for n in range(11, 20):
    data = u'Message number {}'.format(n)
    data = data.encode('utf-8')
    future = publisher.publish(topic_path, data=data)
    logging.info('Published {} of message ID {}.'.format(data, future.result()))

logging.info('Published messages.')

# %%
result.wait_until_finish()
